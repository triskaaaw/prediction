# %%
# Importing important libraries

# For data cleaning and visualization
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# For preprocessing and building model
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import f1_score
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler

# %%
# Membaca dataset retail
train_features = pd.read_csv('train_features.csv')
train_label = pd.read_csv('train_labels.csv')
test = pd.read_csv('test_features.csv')
format = pd.read_csv('submission_format.csv')

# %% [markdown]
# # EDA & Cleaning

# %%
train_features.head(20)
# Out:
#     tahun_kelahiran pendidikan status_pernikahan   pendapatan
# 0              1979    Sarjana   Rencana Menikah          NaN  \
# 1              1950    Sarjana   Rencana Menikah   84063000.0
# 2              1966    Sarjana           Menikah  127532564.0
# 3              1961   Magister   Rencana Menikah  165579620.0
# 4              1970    Sarjana   Rencana Menikah  117703159.0
# 5              1952   Magister           Sendiri   94346105.0
# 6              1963   Magister           Sendiri   75313000.0
# 7              1959    Sarjana   Rencana Menikah  137916316.0
# 8              1957    Sarjana           Sendiri  138069883.0
# 9              1975    Sarjana           Menikah   37567504.0
# 10             1953    Sarjana           Sendiri   34471060.0
# 11             1968        SMA           Menikah  142698390.0
# 12             1957    Sarjana           Sendiri  152418000.0
# 13             1979        SMP           Menikah   14967000.0
# ...

# %%
train_features.loc[train_features['jumlah_anak_balita'].isnull()]
# Out:
#       tahun_kelahiran pendidikan status_pernikahan   pendapatan
# 1                1950    Sarjana   Rencana Menikah   84063000.0  \
# 13               1979        SMP           Menikah   14967000.0
# 17               1973    Sarjana   Rencana Menikah  119766595.0
# 43               1954   Magister   Rencana Menikah  105339251.0
# 52               1956   Magister   Rencana Menikah  190785436.0
# ...               ...        ...               ...          ...
# 3731             1990        SMA           Menikah  125535217.0
# 3783             1966   Magister   Rencana Menikah   65730000.0
# 3792             1956     Doktor   Rencana Menikah  136934000.0
# 3795             1987        SMA           Menikah  165167035.0
# 3798             1968    Sarjana           Sendiri  124682000.0
#
#       jumlah_anak_balita  jumlah_anak_remaja  terakhir_belanja  belanja_buah
# 1                    NaN                 NaN              70.0        6069.0  \
# ...

# %%
train_features.isnull().sum()
# Out:
# tahun_kelahiran               0
# pendidikan                  189
# status_pernikahan           212
# pendapatan                  190
# jumlah_anak_balita          190
# jumlah_anak_remaja          204
# terakhir_belanja            172
# belanja_buah                181
# belanja_daging              178
# belanja_ikan                193
# belanja_kue                 214
# pembelian_diskon            178
# pembelian_web               165
# pembelian_toko              169
# keluhan                     196
# tanggal_menjadi_anggota    2752
# dtype: int64

# %%
train_features.columns
# Out:
# Index(['tahun_kelahiran', 'pendidikan', 'status_pernikahan', 'pendapatan',
#        'jumlah_anak_balita', 'jumlah_anak_remaja', 'terakhir_belanja',
#        'belanja_buah', 'belanja_daging', 'belanja_ikan', 'belanja_kue',
#        'pembelian_diskon', 'pembelian_web', 'pembelian_toko', 'keluhan',
#        'tanggal_menjadi_anggota'],
#       dtype='object')

# %%
test.head()
# Out:
#      ID  tahun_kelahiran pendidikan status_pernikahan   pendapatan
# 0  2241             1957    Sarjana               NaN  120660151.0  \
# 1  2274             1968     Doktor           Menikah  163551821.0
# 2  1107             1968        SMA           Menikah   29857000.0
# 3  4478             1971     Doktor           Menikah  117949098.0
# 4  5080             1974    Sarjana   Rencana Menikah  164761134.0
#
#    jumlah_anak_balita  jumlah_anak_remaja  terakhir_belanja  belanja_buah
# 0                 0.0                 1.0              63.0      122277.0  \
# 1                 0.0                 1.0              58.0       35761.0
# 2                 0.0                 0.0              34.0        8092.0
# 3                 0.0                 1.0              82.0        4872.0
# 4                 0.0                 0.0              28.0      343208.0
#
#    belanja_daging  belanja_ikan  belanja_kue  pembelian_diskon  pembelian_web
# ...

# %%
test.columns
# Out:
# Index(['ID', 'tahun_kelahiran', 'pendidikan', 'status_pernikahan',
#        'pendapatan', 'jumlah_anak_balita', 'jumlah_anak_remaja',
#        'terakhir_belanja', 'belanja_buah', 'belanja_daging', 'belanja_ikan',
#        'belanja_kue', 'pembelian_diskon', 'pembelian_web', 'pembelian_toko',
#        'keluhan', 'tanggal_menjadi_anggota'],
#       dtype='object')

# %%
train_features.dtypes
# Out:
# tahun_kelahiran              int64
# pendidikan                  object
# status_pernikahan           object
# pendapatan                 float64
# jumlah_anak_balita         float64
# jumlah_anak_remaja         float64
# terakhir_belanja           float64
# belanja_buah               float64
# belanja_daging             float64
# belanja_ikan               float64
# belanja_kue                float64
# pembelian_diskon           float64
# pembelian_web              float64
# pembelian_toko             float64
# keluhan                    float64
# tanggal_menjadi_anggota     object
# dtype: object

# %%
# menggabungkan dataset train

train = pd.concat([train_features, train_label], axis=1)
train
# Out:
#       tahun_kelahiran pendidikan status_pernikahan   pendapatan
# 0                1979    Sarjana   Rencana Menikah          NaN  \
# 1                1950    Sarjana   Rencana Menikah   84063000.0
# 2                1966    Sarjana           Menikah  127532564.0
# 3                1961   Magister   Rencana Menikah  165579620.0
# 4                1970    Sarjana   Rencana Menikah  117703159.0
# ...               ...        ...               ...          ...
# 3812             1955   Magister           Menikah   78199470.0
# 3813             1947     Doktor   Rencana Menikah  109306000.0
# 3814             1974   Magister           Menikah  104621000.0
# 3815             1957        SMA   Rencana Menikah  110850000.0
# 3816             1961    Sarjana           Menikah  130512000.0
#
#       jumlah_anak_balita  jumlah_anak_remaja  terakhir_belanja  belanja_buah
# 0                    0.0                 1.0               NaN       50575.0  \
# ...

# %%
train.isnull().sum()
# Out:
# tahun_kelahiran               0
# pendidikan                  189
# status_pernikahan           212
# pendapatan                  190
# jumlah_anak_balita          190
# jumlah_anak_remaja          204
# terakhir_belanja            172
# belanja_buah                181
# belanja_daging              178
# belanja_ikan                193
# belanja_kue                 214
# pembelian_diskon            178
# pembelian_web               165
# pembelian_toko              169
# keluhan                     196
# tanggal_menjadi_anggota    2752
# jumlah_promosi                0
# dtype: int64

# %%
# Menangani null pada pendidikan dan status_pernikahan 

train['pendidikan'].fillna('Unknown', inplace=True)
train['status_pernikahan'].fillna('Unknown', inplace=True)

test['pendidikan'].fillna('Unknown', inplace=True)
test['status_pernikahan'].fillna('Unknown', inplace=True)

# %%
# Mengatasi nilai null pada belanja_buah, belanja_daging, belanja_ikan, belanja_kue

train['belanja_buah'].fillna(0, inplace=True)
train['belanja_daging'].fillna(0, inplace=True)
train['belanja_ikan'].fillna(0, inplace=True)
train['belanja_kue'].fillna(0, inplace=True)

test['belanja_daging'].fillna(0, inplace=True)
test['belanja_ikan'].fillna(0, inplace=True)
test['belanja_kue'].fillna(0, inplace=True)
test['belanja_buah'].fillna(0, inplace=True)

# %%
train.isnull().sum()
# Out:
# tahun_kelahiran               0
# pendidikan                    0
# status_pernikahan             0
# pendapatan                  190
# jumlah_anak_balita          190
# jumlah_anak_remaja          204
# terakhir_belanja            172
# belanja_buah                  0
# belanja_daging                0
# belanja_ikan                  0
# belanja_kue                   0
# pembelian_diskon            178
# pembelian_web               165
# pembelian_toko              169
# keluhan                     196
# tanggal_menjadi_anggota    2752
# jumlah_promosi                0
# dtype: int64

# %%
# meangani null pada jumlah_anak_balita, jumlah_anak_remaja, terakhir_belanja, pembelian_diskon, pembelian_web, pembelian_toko, keluhan

train['jumlah_anak_balita'].fillna(0, inplace=True)
train['jumlah_anak_remaja'].fillna(0, inplace=True)
train['terakhir_belanja'].fillna(0, inplace=True)
train['pembelian_diskon'].fillna(0, inplace=True)
train['pembelian_web'].fillna(0, inplace=True)
train['pembelian_toko'].fillna(0, inplace=True)
train['keluhan'].fillna(0, inplace=True)


test['jumlah_anak_balita'].fillna(0, inplace=True)
test['jumlah_anak_remaja'].fillna(0, inplace=True)
test['terakhir_belanja'].fillna(0, inplace=True)
test['pembelian_diskon'].fillna(0, inplace=True)
test['pembelian_web'].fillna(0, inplace=True)
test['pembelian_toko'].fillna(0, inplace=True)
test['keluhan'].fillna(0, inplace=True)

# %%
# menangani null pada pendapatan

# Mengganti Nilai Null dengan nilai unknown pada kolom education

train['pendapatan'].fillna(0, inplace=True)
train['tanggal_menjadi_anggota'].fillna('Unknown', inplace=True)


test['pendapatan'].fillna(0, inplace=True)
test['tanggal_menjadi_anggota'].fillna('Unknown', inplace=True)

# %%
train.isnull().sum()
# Out:
# tahun_kelahiran            0
# pendidikan                 0
# status_pernikahan          0
# pendapatan                 0
# jumlah_anak_balita         0
# jumlah_anak_remaja         0
# terakhir_belanja           0
# belanja_buah               0
# belanja_daging             0
# belanja_ikan               0
# belanja_kue                0
# pembelian_diskon           0
# pembelian_web              0
# pembelian_toko             0
# keluhan                    0
# tanggal_menjadi_anggota    0
# jumlah_promosi             0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# ID                         0
# tahun_kelahiran            0
# pendidikan                 0
# status_pernikahan          0
# pendapatan                 0
# jumlah_anak_balita         0
# jumlah_anak_remaja         0
# terakhir_belanja           0
# belanja_buah               0
# belanja_daging             0
# belanja_ikan               0
# belanja_kue                0
# pembelian_diskon           0
# pembelian_web              0
# pembelian_toko             0
# keluhan                    0
# tanggal_menjadi_anggota    0
# dtype: int64

# %%
for col in train.columns:
    print(col)
    print(train[col].unique())
    print()
# Out:
# tahun_kelahiran
# [1979 1950 1966 1961 1970 1952 1963 1959 1957 1975 1953 1968 1983 1977
#  1973 1969 1980 1965 1960 1982 1971 1972 1958 1944 1986 1962 1967 1984
#  1976 1964 1954 1956 1978 1991 1981 1946 1974 1947 1955 1989 1945 1948
#  1990 1951 1988 1949 1985 1943 1996 1987 1909 1993 1992 1925 1912 1999
#  1941 1995 1994 1916 1942 1998 1899 1902 1922 2000 1918 1920 1997 1929
#  1940 1932 1924 1900 1914 1908]
#
# pendidikan
# ['Sarjana' 'Magister' 'SMA' 'SMP' 'Doktor' 'Unknown' '5']
#
# status_pernikahan
# ['Rencana Menikah' 'Menikah' 'Sendiri' 'Cerai' 'Unknown' 'Cerai Mati' '5']
#
# pendapatan
# [0.00000000e+00 8.40630000e+07 1.27532564e+08 ... 1.04621000e+08
#  1.10850000e+08 1.30512000e+08]
#
# jumlah_anak_balita
# [0. 1. 2.]
#
# jumlah_anak_remaja
# [1. 0. 2.]
#
# terakhir_belanja
# [  0.  70.  45.  90.  78.   9.  96.  21.  26.  67.  59.  57.   5.  65.
#   61.  25.  16.  50.  69.  84.  56.  54.  17.  51.  29.  73.  60.  87.
# ...

# %%
for col in test.columns:
    print(col)
    print(test[col].unique())
    print()
# Out:
# ID
# [2241 2274 1107 ... 3478   89 2151]
#
# tahun_kelahiran
# [1957 1968 1971 1974 1972 1963 1956 1954 1946 1983 1985 1959 1962 1961
#  1978 1979 1984 1969 1951 1960 1990 1988 1970 1989 1967 1981 1977 1945
#  1965 1980 1976 1966 1975 1982 1958 1987 1950 1953 1952 1973 1992 1986
#  1941 1955 1949 1964 1991 1948 1913 1904 1947 1943 1903 1994 1998 1993
#  1902 1933 1935 1944 1938 1932 1999 1934 1942 1937 1939 2000 1892 2005
#  1995 1922 1929 2009 2006 1997 1918 1940 1996 1914 1912 1915 1926 1924
#  1920]
#
# pendidikan
# ['Sarjana' 'Doktor' 'SMA' 'Magister' 'Unknown' 'SMP' '5']
#
# status_pernikahan
# ['Unknown' 'Menikah' 'Rencana Menikah' 'Sendiri' 'Cerai Mati' 'Cerai' '5']
#
# pendapatan
# [1.20660151e+08 1.63551821e+08 2.98570000e+07 ... 8.40589230e+07
#  1.06301000e+08 1.40353000e+08]
#
# jumlah_anak_balita
# [0. 1. 2.]
#
# jumlah_anak_remaja
# [1. 0. 2.]
#
# terakhir_belanja
# [ 63.  58.  34.  82.  28.  32.  46.  37.  11.  73.  12.  22.  75.  51.
# ...

# %%
# menangani nilai '5' pada pendidikan dan status_pernikahan

train['pendidikan'] = train['pendidikan'].replace('5', 'Unknown')
train['status_pernikahan'] = train['status_pernikahan'].replace('5', 'Unknown')

test['status_pernikahan'] = test['status_pernikahan'].replace('5', 'Unknown')
test['pendidikan'] = test['pendidikan'].replace('5', 'Unknown')

# %%
for col in train.columns:
    print(col)
    print(train[col].unique())
    print()
# Out:
# tahun_kelahiran
# [1979 1950 1966 1961 1970 1952 1963 1959 1957 1975 1953 1968 1983 1977
#  1973 1969 1980 1965 1960 1982 1971 1972 1958 1944 1986 1962 1967 1984
#  1976 1964 1954 1956 1978 1991 1981 1946 1974 1947 1955 1989 1945 1948
#  1990 1951 1988 1949 1985 1943 1996 1987 1909 1993 1992 1925 1912 1999
#  1941 1995 1994 1916 1942 1998 1899 1902 1922 2000 1918 1920 1997 1929
#  1940 1932 1924 1900 1914 1908]
#
# pendidikan
# ['Sarjana' 'Magister' 'SMA' 'SMP' 'Doktor' 'Unknown']
#
# status_pernikahan
# ['Rencana Menikah' 'Menikah' 'Sendiri' 'Cerai' 'Unknown' 'Cerai Mati']
#
# pendapatan
# [0.00000000e+00 8.40630000e+07 1.27532564e+08 ... 1.04621000e+08
#  1.10850000e+08 1.30512000e+08]
#
# jumlah_anak_balita
# [0. 1. 2.]
#
# jumlah_anak_remaja
# [1. 0. 2.]
#
# terakhir_belanja
# [  0.  70.  45.  90.  78.   9.  96.  21.  26.  67.  59.  57.   5.  65.
#   61.  25.  16.  50.  69.  84.  56.  54.  17.  51.  29.  73.  60.  87.
# ...

# %%
for col in test.columns:
    print(col)
    print(test[col].unique())
    print()
# Out:
# ID
# [2241 2274 1107 ... 3478   89 2151]
#
# tahun_kelahiran
# [1957 1968 1971 1974 1972 1963 1956 1954 1946 1983 1985 1959 1962 1961
#  1978 1979 1984 1969 1951 1960 1990 1988 1970 1989 1967 1981 1977 1945
#  1965 1980 1976 1966 1975 1982 1958 1987 1950 1953 1952 1973 1992 1986
#  1941 1955 1949 1964 1991 1948 1913 1904 1947 1943 1903 1994 1998 1993
#  1902 1933 1935 1944 1938 1932 1999 1934 1942 1937 1939 2000 1892 2005
#  1995 1922 1929 2009 2006 1997 1918 1940 1996 1914 1912 1915 1926 1924
#  1920]
#
# pendidikan
# ['Sarjana' 'Doktor' 'SMA' 'Magister' 'Unknown' 'SMP']
#
# status_pernikahan
# ['Unknown' 'Menikah' 'Rencana Menikah' 'Sendiri' 'Cerai Mati' 'Cerai']
#
# pendapatan
# [1.20660151e+08 1.63551821e+08 2.98570000e+07 ... 8.40589230e+07
#  1.06301000e+08 1.40353000e+08]
#
# jumlah_anak_balita
# [0. 1. 2.]
#
# jumlah_anak_remaja
# [1. 0. 2.]
#
# terakhir_belanja
# [ 63.  58.  34.  82.  28.  32.  46.  37.  11.  73.  12.  22.  75.  51.
# ...

# %%
# ubah tipe data tanggal_menjadi_anggota

# train['tanggal_menjadi_anggota'] = train['tanggal_menjadi_anggota'].astype(dtype='datetime64[ns]')
# test['tanggal_menjadi_anggota'] = test['tanggal_menjadi_anggota'].astype(dtype='datetime64[ns]')

# %%
# Menambahkan kolom baru di train

train['TotalAmount'] = train['belanja_buah'] + train['belanja_daging'] + train['belanja_ikan'] + train['belanja_kue']
train
# Out:
#       tahun_kelahiran pendidikan status_pernikahan   pendapatan
# 0                1979    Sarjana   Rencana Menikah          0.0  \
# 1                1950    Sarjana   Rencana Menikah   84063000.0
# 2                1966    Sarjana           Menikah  127532564.0
# 3                1961   Magister   Rencana Menikah  165579620.0
# 4                1970    Sarjana   Rencana Menikah  117703159.0
# ...               ...        ...               ...          ...
# 3812             1955   Magister           Menikah   78199470.0
# 3813             1947     Doktor   Rencana Menikah  109306000.0
# 3814             1974   Magister           Menikah  104621000.0
# 3815             1957        SMA   Rencana Menikah  110850000.0
# 3816             1961    Sarjana           Menikah  130512000.0
#
#       jumlah_anak_balita  jumlah_anak_remaja  terakhir_belanja  belanja_buah
# 0                    0.0                 1.0               0.0       50575.0  \
# ...

# %%
# Menambahkan kolom baru di test

test['TotalAmount'] = test['belanja_buah'] + test['belanja_daging'] + test['belanja_ikan'] + test['belanja_kue']
test
# Out:
#         ID  tahun_kelahiran pendidikan status_pernikahan   pendapatan
# 0     2241             1957    Sarjana           Unknown  120660151.0  \
# 1     2274             1968     Doktor           Menikah  163551821.0
# 2     1107             1968        SMA           Menikah   29857000.0
# 3     4478             1971     Doktor           Menikah  117949098.0
# 4     5080             1974    Sarjana   Rencana Menikah  164761134.0
# ...    ...              ...        ...               ...          ...
# 3813   271             1984   Magister           Sendiri   66320000.0
# 3814  3334             1972    Sarjana           Menikah  159651946.0
# 3815  3478             1968   Magister   Rencana Menikah   84058923.0
# 3816    89             1966    Sarjana   Rencana Menikah  106301000.0
# 3817  2151             1973    Sarjana           Menikah  140353000.0
#
#       jumlah_anak_balita  jumlah_anak_remaja  terakhir_belanja  belanja_buah
# ...

# %% [markdown]
# # Outlier

# %%
# check outlier
cols = ['tahun_kelahiran', 'pendidikan', 'status_pernikahan', 'pendapatan',
       'jumlah_anak_balita', 'jumlah_anak_remaja', 'terakhir_belanja',
       'belanja_buah', 'belanja_daging', 'belanja_ikan', 'belanja_kue',
       'pembelian_diskon', 'pembelian_web', 'pembelian_toko', 'keluhan',
       'tanggal_menjadi_anggota', 'jumlah_promosi', 'TotalAmount']

# menentukan ukuran gambar plot
train[cols].boxplot(figsize=(40,20))

plt.title('Cek Outlier', fontsize=20)
plt.xlabel('Variabel', fontsize=15)
plt.ylabel('Nilai', fontsize=15)
plt.show()

# %% [markdown]
# ## Handling Outlier

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3817 entries, 0 to 3816
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tahun_kelahiran          3817 non-null   int64
#  1   pendidikan               3817 non-null   object
#  2   status_pernikahan        3817 non-null   object
#  3   pendapatan               3817 non-null   float64
#  4   jumlah_anak_balita       3817 non-null   float64
#  5   jumlah_anak_remaja       3817 non-null   float64
#  6   terakhir_belanja         3817 non-null   float64
#  7   belanja_buah             3817 non-null   float64
#  8   belanja_daging           3817 non-null   float64
#  9   belanja_ikan             3817 non-null   float64
#  10  belanja_kue              3817 non-null   float64
#  11  pembelian_diskon         3817 non-null   float64
#  12  pembelian_web            3817 non-null   float64
# ...

# %%
# Handling 'pendapatan'
q1 = train['pendapatan'].quantile(0.25)
q3 = train['pendapatan'].quantile(0.75)
iqr = q3 - q1
batas_bawah = q1 - 1.5 * iqr
batas_atas = q3 + 1.5 * iqr
print('batas_bawah : ', batas_bawah)
print('batas_atas : ', batas_atas)

# Mengganti nilai 'pendapatan' yang lebih besar dari batas atas dengan nilai batas atas itu sendiri.
# Ini dilakukan agar tidak ada nilai yang melebihi batas atas.
train['pendapatan'] = np.where(train['pendapatan'] > batas_atas, batas_atas, train['pendapatan'])

# Mengganti nilai 'pendapatan' yang lebih kecil dari batas bawah dengan nilai batas bawah itu sendiri.
# Ini dilakukan agar tidak ada nilai yang kurang dari batas bawah.
train['pendapatan'] = np.where(train['pendapatan'] < batas_bawah, batas_bawah, train['pendapatan'])
# Out:
# batas_bawah :  -27240442.0
# batas_atas :  253069790.0

# %%
# Handling 'terakhir_belanja'
q1 = train['terakhir_belanja'].quantile(0.25)
q3 = train['terakhir_belanja'].quantile(0.75)
iqr = q3 - q1
batas_bawah = q1 - 1.5 * iqr
batas_atas = q3 + 1.5 * iqr
print('batas_bawah : ',batas_bawah)
print('batas_atas : ',batas_atas)

#Mengganti nilai 'terakhir_belanja' yang lebih besar dari batas atas dengan nilai batas atas itu sendiri. Ini dilakukan agar tidak ada nilai yang melebihi batas atas.
train['terakhir_belanja'] = np.where(train['terakhir_belanja'] > batas_atas, batas_atas, train['terakhir_belanja'])

#Mengganti nilai 'terakhir_belanja' yang lebih kecil dari batas bawah dengan nilai batas bawah itu sendiri. Ini dilakukan agar tidak ada nilai yang kurang dari batas bawah.
train['terakhir_belanja'] = np.where(train['terakhir_belanja'] < batas_bawah, batas_bawah, train['terakhir_belanja'])
# Out:
# batas_bawah :  -47.0
# batas_atas :  137.0

# %%
# Handling 'belanja_buah'
q1 = train['belanja_buah'].quantile(0.25)
q3 = train['belanja_buah'].quantile(0.75)
iqr = q3 - q1
batas_bawah = q1 - 1.5 * iqr
batas_atas = q3 + 1.5 * iqr
print('batas_bawah : ',batas_bawah)
print('batas_atas : ',batas_atas)

#Mengganti nilai 'belanja_buah' yang lebih besar dari batas atas dengan nilai batas atas itu sendiri. Ini dilakukan agar tidak ada nilai yang melebihi batas atas.
train['belanja_buah'] = np.where(train['belanja_buah'] > batas_atas, batas_atas, train['belanja_buah'])

#Mengganti nilai 'belanja_buah' yang lebih kecil dari batas bawah dengan nilai batas bawah itu sendiri. Ini dilakukan agar tidak ada nilai yang kurang dari batas bawah.
train['belanja_buah'] = np.where(train['belanja_buah'] < batas_bawah, batas_bawah, train['belanja_buah'])
# Out:
# batas_bawah :  -107437.5
# batas_atas :  195246.5

# %%
# Handling 'belanja_daging'
q1 = train['belanja_daging'].quantile(0.25)
q3 = train['belanja_daging'].quantile(0.75)
iqr = q3 - q1
batas_bawah = q1 - 1.5 * iqr
batas_atas = q3 + 1.5 * iqr
print('batas_bawah : ',batas_bawah)
print('batas_atas : ',batas_atas)

#Mengganti nilai 'belanja_daging' yang lebih besar dari batas atas dengan nilai batas atas itu sendiri. Ini dilakukan agar tidak ada nilai yang melebihi batas atas.
train['belanja_daging'] = np.where(train['belanja_daging'] > batas_atas, batas_atas, train['belanja_daging'])

#Mengganti nilai 'belanja_daging' yang lebih kecil dari batas bawah dengan nilai batas bawah itu sendiri. Ini dilakukan agar tidak ada nilai yang kurang dari batas bawah.
train['belanja_daging'] = np.where(train['belanja_daging'] < batas_bawah, batas_bawah, train['belanja_daging'])
# Out:
# batas_bawah :  -862958.5
# batas_atas :  1542405.5

# %%
# Handling 'belanja_ikan'
q1 = train['belanja_ikan'].quantile(0.25)
q3 = train['belanja_ikan'].quantile(0.75)
iqr = q3 - q1
batas_bawah = q1 - 1.5 * iqr
batas_atas = q3 + 1.5 * iqr
print('batas_bawah : ',batas_bawah)
print('batas_atas : ',batas_atas)

#Mengganti nilai 'belanja_ikan' yang lebih besar dari batas atas dengan nilai batas atas itu sendiri. Ini dilakukan agar tidak ada nilai yang melebihi batas atas.
train['belanja_ikan'] = np.where(train['belanja_ikan'] > batas_atas, batas_atas, train['belanja_ikan'])

#Mengganti nilai 'belanja_ikan' yang lebih kecil dari batas bawah dengan nilai batas bawah itu sendiri. Ini dilakukan agar tidak ada nilai yang kurang dari batas bawah.
train['belanja_ikan'] = np.where(train['belanja_ikan'] < batas_bawah, batas_bawah, train['belanja_ikan'])
# Out:
# batas_bawah :  -153010.5
# batas_atas :  275865.5

# %%
# Handling 'belanja_kue'
q1 = train['belanja_kue'].quantile(0.25)
q3 = train['belanja_kue'].quantile(0.75)
iqr = q3 - q1
batas_bawah = q1 - 1.5 * iqr
batas_atas = q3 + 1.5 * iqr
print('batas_bawah : ',batas_bawah)
print('batas_atas : ',batas_atas)

#Mengganti nilai 'belanja_kue' yang lebih besar dari batas atas dengan nilai batas atas itu sendiri. Ini dilakukan agar tidak ada nilai yang melebihi batas atas.
train['belanja_kue'] = np.where(train['belanja_kue'] > batas_atas, batas_atas, train['belanja_kue'])

#Mengganti nilai 'belanja_kue' yang lebih kecil dari batas bawah dengan nilai batas bawah itu sendiri. Ini dilakukan agar tidak ada nilai yang kurang dari batas bawah.
train['belanja_kue'] = np.where(train['belanja_kue'] < batas_bawah, batas_bawah, train['belanja_kue'])
# Out:
# batas_bawah :  -112625.5
# batas_atas :  202810.5

# %%
# Handling 'pembelian_diskon'
q1 = train['pembelian_diskon'].quantile(0.25)
q3 = train['pembelian_diskon'].quantile(0.75)
iqr = q3 - q1
batas_bawah = q1 - 1.5 * iqr
batas_atas = q3 + 1.5 * iqr
print('batas_bawah : ',batas_bawah)
print('batas_atas : ',batas_atas)

#Mengganti nilai 'pembelian_diskon' yang lebih besar dari batas atas dengan nilai batas atas itu sendiri. Ini dilakukan agar tidak ada nilai yang melebihi batas atas.
train['pembelian_diskon'] = np.where(train['pembelian_diskon'] > batas_atas, batas_atas, train['pembelian_diskon'])

#Mengganti nilai 'pembelian_diskon' yang lebih kecil dari batas bawah dengan nilai batas bawah itu sendiri. Ini dilakukan agar tidak ada nilai yang kurang dari batas bawah.
train['pembelian_diskon'] = np.where(train['pembelian_diskon'] < batas_bawah, batas_bawah, train['pembelian_diskon'])
# Out:
# batas_bawah :  -4.5
# batas_atas :  7.5

# %%
# Handling 'pembelian_web'
q1 = train['pembelian_web'].quantile(0.25)
q3 = train['pembelian_web'].quantile(0.75)
iqr = q3 - q1
batas_bawah = q1 - 1.5 * iqr
batas_atas = q3 + 1.5 * iqr
print('batas_bawah : ',batas_bawah)
print('batas_atas : ',batas_atas)

#Mengganti nilai 'pembelian_web' yang lebih besar dari batas atas dengan nilai batas atas itu sendiri. Ini dilakukan agar tidak ada nilai yang melebihi batas atas.
train['pembelian_web'] = np.where(train['pembelian_web'] > batas_atas, batas_atas, train['pembelian_web'])

#Mengganti nilai 'pembelian_web' yang lebih kecil dari batas bawah dengan nilai batas bawah itu sendiri. Ini dilakukan agar tidak ada nilai yang kurang dari batas bawah.
train['pembelian_web'] = np.where(train['pembelian_web'] < batas_bawah, batas_bawah, train['pembelian_web'])
# Out:
# batas_bawah :  -4.0
# batas_atas :  12.0

# %%
# Handling 'pembelian_toko'
q1 = train['pembelian_toko'].quantile(0.25)
q3 = train['pembelian_toko'].quantile(0.75)
iqr = q3 - q1
batas_bawah = q1 - 1.5 * iqr
batas_atas = q3 + 1.5 * iqr
print('batas_bawah : ',batas_bawah)
print('batas_atas : ',batas_atas)

#Mengganti nilai 'pembelian_toko' yang lebih besar dari batas atas dengan nilai batas atas itu sendiri. Ini dilakukan agar tidak ada nilai yang melebihi batas atas.
train['pembelian_toko'] = np.where(train['pembelian_toko'] > batas_atas, batas_atas, train['pembelian_toko'])

#Mengganti nilai 'pembelian_toko' yang lebih kecil dari batas bawah dengan nilai batas bawah itu sendiri. Ini dilakukan agar tidak ada nilai yang kurang dari batas bawah.
train['pembelian_toko'] = np.where(train['pembelian_toko'] < batas_bawah, batas_bawah, train['pembelian_toko'])
# Out:
# batas_bawah :  -4.5
# batas_atas :  15.5

# %%
# Handling 'TotalAmount'
q1 = train['TotalAmount'].quantile(0.25)
q3 = train['TotalAmount'].quantile(0.75)
iqr = q3 - q1
batas_bawah = q1 - 1.5 * iqr
batas_atas = q3 + 1.5 * iqr
print('batas_bawah : ',batas_bawah)
print('batas_atas : ',batas_atas)

#Mengganti nilai 'TotalAmount' yang lebih besar dari batas atas dengan nilai batas atas itu sendiri. Ini dilakukan agar tidak ada nilai yang melebihi batas atas.
train['TotalAmount'] = np.where(train['TotalAmount'] > batas_atas, batas_atas, train['TotalAmount'])

#Mengganti nilai 'TotalAmount' yang lebih kecil dari batas bawah dengan nilai batas bawah itu sendiri. Ini dilakukan agar tidak ada nilai yang kurang dari batas bawah.
train['TotalAmount'] = np.where(train['TotalAmount'] < batas_bawah, batas_bawah, train['TotalAmount'])
# Out:
# batas_bawah :  -1302495.5
# batas_atas :  2386612.5

# %%
# Setelah di handling
cols = ['tahun_kelahiran', 'pendidikan', 'status_pernikahan', 'pendapatan',
       'jumlah_anak_balita', 'jumlah_anak_remaja', 'terakhir_belanja',
       'belanja_buah', 'belanja_daging', 'belanja_ikan', 'belanja_kue',
       'pembelian_diskon', 'pembelian_web', 'pembelian_toko', 'keluhan',
       'tanggal_menjadi_anggota', 'jumlah_promosi', 'TotalAmount']

train[cols].boxplot(figsize=(40,10))
plt.title('Cek Outlier', fontsize=20)
plt.xlabel('Variabel', fontsize=15)
plt.ylabel('Nilai', fontsize=15)
plt.show()

# %% [markdown]
# # Encoding

# %%
# Buat dictionary untuk mapping nilai pendidikan ke angka
mapping_pendidikan = {'SMP': 1, 'SMA': 2, 'Sarjana': 3, 'Magister': 4,
           'Doktor': 5, 'Unknown' : 6}

# Encode kolom 'pendidikan' menggunakan mapping
train['pendidikan'] = train['pendidikan'].map(mapping_pendidikan)
train
# Out:
#       tahun_kelahiran  pendidikan status_pernikahan   pendapatan
# 0                1979           3   Rencana Menikah          0.0  \
# 1                1950           3   Rencana Menikah   84063000.0
# 2                1966           3           Menikah  127532564.0
# 3                1961           4   Rencana Menikah  165579620.0
# 4                1970           3   Rencana Menikah  117703159.0
# ...               ...         ...               ...          ...
# 3812             1955           4           Menikah   78199470.0
# 3813             1947           5   Rencana Menikah  109306000.0
# 3814             1974           4           Menikah  104621000.0
# 3815             1957           2   Rencana Menikah  110850000.0
# 3816             1961           3           Menikah  130512000.0
#
#       jumlah_anak_balita  jumlah_anak_remaja  terakhir_belanja  belanja_buah
# 0                    0.0                 1.0               0.0       50575.0  \
# ...

# %%
# Encode kolom 'pendidikan' menggunakan mapping
test['pendidikan'] = test['pendidikan'].map(mapping_pendidikan)
test
# Out:
#         ID  tahun_kelahiran  pendidikan status_pernikahan   pendapatan
# 0     2241             1957           3           Unknown  120660151.0  \
# 1     2274             1968           5           Menikah  163551821.0
# 2     1107             1968           2           Menikah   29857000.0
# 3     4478             1971           5           Menikah  117949098.0
# 4     5080             1974           3   Rencana Menikah  164761134.0
# ...    ...              ...         ...               ...          ...
# 3813   271             1984           4           Sendiri   66320000.0
# 3814  3334             1972           3           Menikah  159651946.0
# 3815  3478             1968           4   Rencana Menikah   84058923.0
# 3816    89             1966           3   Rencana Menikah  106301000.0
# 3817  2151             1973           3           Menikah  140353000.0
#
#       jumlah_anak_balita  jumlah_anak_remaja  terakhir_belanja  belanja_buah
# ...

# %%
# Buat dictionary untuk mapping nilai status_pernikahan ke angka
mapping_status = {'Sendiri': 1, 'Rencana Menikah': 2, 'Menikah': 3, 'Cerai': 4,
           'Cerai Mati': 5, 'Unknown': 6}

# Encode kolom 'status_pernikahan' menggunakan mapping
train['status_pernikahan'] = train['status_pernikahan'].map(mapping_status)
train
# Out:
#       tahun_kelahiran  pendidikan  status_pernikahan   pendapatan
# 0                1979           3                  2          0.0  \
# 1                1950           3                  2   84063000.0
# 2                1966           3                  3  127532564.0
# 3                1961           4                  2  165579620.0
# 4                1970           3                  2  117703159.0
# ...               ...         ...                ...          ...
# 3812             1955           4                  3   78199470.0
# 3813             1947           5                  2  109306000.0
# 3814             1974           4                  3  104621000.0
# 3815             1957           2                  2  110850000.0
# 3816             1961           3                  3  130512000.0
#
#       jumlah_anak_balita  jumlah_anak_remaja  terakhir_belanja  belanja_buah
# 0                    0.0                 1.0               0.0       50575.0  \
# ...

# %%
# Encode kolom 'status_pernikahan' menggunakan mapping
test['status_pernikahan'] = test['status_pernikahan'].map(mapping_status)
test
# Out:
#         ID  tahun_kelahiran  pendidikan  status_pernikahan   pendapatan
# 0     2241             1957           3                  6  120660151.0  \
# 1     2274             1968           5                  3  163551821.0
# 2     1107             1968           2                  3   29857000.0
# 3     4478             1971           5                  3  117949098.0
# 4     5080             1974           3                  2  164761134.0
# ...    ...              ...         ...                ...          ...
# 3813   271             1984           4                  1   66320000.0
# 3814  3334             1972           3                  3  159651946.0
# 3815  3478             1968           4                  2   84058923.0
# 3816    89             1966           3                  2  106301000.0
# 3817  2151             1973           3                  3  140353000.0
#
#       jumlah_anak_balita  jumlah_anak_remaja  terakhir_belanja  belanja_buah
# ...

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

train.tanggal_menjadi_anggota = le.fit_transform(train.tanggal_menjadi_anggota)
test.tanggal_menjadi_anggota = le.fit_transform(test.tanggal_menjadi_anggota)

# %%
for col in train.columns:
    print(col)
    print(train[col].unique())
    print()
# Out:
# tahun_kelahiran
# [1979 1950 1966 1961 1970 1952 1963 1959 1957 1975 1953 1968 1983 1977
#  1973 1969 1980 1965 1960 1982 1971 1972 1958 1944 1986 1962 1967 1984
#  1976 1964 1954 1956 1978 1991 1981 1946 1974 1947 1955 1989 1945 1948
#  1990 1951 1988 1949 1985 1943 1996 1987 1909 1993 1992 1925 1912 1999
#  1941 1995 1994 1916 1942 1998 1899 1902 1922 2000 1918 1920 1997 1929
#  1940 1932 1924 1900 1914 1908]
#
# pendidikan
# [3 4 2 1 5 6]
#
# status_pernikahan
# [2 3 1 4 6 5]
#
# pendapatan
# [0.00000000e+00 8.40630000e+07 1.27532564e+08 ... 1.04621000e+08
#  1.10850000e+08 1.30512000e+08]
#
# jumlah_anak_balita
# [0. 1. 2.]
#
# jumlah_anak_remaja
# [1. 0. 2.]
#
# terakhir_belanja
# [  0.  70.  45.  90.  78.   9.  96.  21.  26.  67.  59.  57.   5.  65.
#   61.  25.  16.  50.  69.  84.  56.  54.  17.  51.  29.  73.  60.  87.
#   62.  41.  35.   3.  36.  58.  64.  55.  12.  19.  30.  28.  11. 114.
#    4.  76.  85.  15.  80.  81.  37.  47.  18.  20.   6.  77.  22.  32.
# ...

# %%
for col in test.columns:
    print(col)
    print(test[col].unique())
    print()
# Out:
# ID
# [2241 2274 1107 ... 3478   89 2151]
#
# tahun_kelahiran
# [1957 1968 1971 1974 1972 1963 1956 1954 1946 1983 1985 1959 1962 1961
#  1978 1979 1984 1969 1951 1960 1990 1988 1970 1989 1967 1981 1977 1945
#  1965 1980 1976 1966 1975 1982 1958 1987 1950 1953 1952 1973 1992 1986
#  1941 1955 1949 1964 1991 1948 1913 1904 1947 1943 1903 1994 1998 1993
#  1902 1933 1935 1944 1938 1932 1999 1934 1942 1937 1939 2000 1892 2005
#  1995 1922 1929 2009 2006 1997 1918 1940 1996 1914 1912 1915 1926 1924
#  1920]
#
# pendidikan
# [3 5 2 4 6 1]
#
# status_pernikahan
# [6 3 2 1 5 4]
#
# pendapatan
# [1.20660151e+08 1.63551821e+08 2.98570000e+07 ... 8.40589230e+07
#  1.06301000e+08 1.40353000e+08]
#
# jumlah_anak_balita
# [0. 1. 2.]
#
# jumlah_anak_remaja
# [1. 0. 2.]
#
# terakhir_belanja
# [ 63.  58.  34.  82.  28.  32.  46.  37.  11.  73.  12.  22.  75.  51.
#   74.  24.  33.  66.   4.  52.  15.  41.  31. 113.  18.  68.   0.  29.
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3817 entries, 0 to 3816
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tahun_kelahiran          3817 non-null   int64
#  1   pendidikan               3817 non-null   int64
#  2   status_pernikahan        3817 non-null   int64
#  3   pendapatan               3817 non-null   float64
#  4   jumlah_anak_balita       3817 non-null   float64
#  5   jumlah_anak_remaja       3817 non-null   float64
#  6   terakhir_belanja         3817 non-null   float64
#  7   belanja_buah             3817 non-null   float64
#  8   belanja_daging           3817 non-null   float64
#  9   belanja_ikan             3817 non-null   float64
#  10  belanja_kue              3817 non-null   float64
#  11  pembelian_diskon         3817 non-null   float64
#  12  pembelian_web            3817 non-null   float64
#  13  pembelian_toko           3817 non-null   float64
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       3818 non-null   int64
#  1   tahun_kelahiran          3818 non-null   int64
#  2   pendidikan               3818 non-null   int64
#  3   status_pernikahan        3818 non-null   int64
#  4   pendapatan               3818 non-null   float64
#  5   jumlah_anak_balita       3818 non-null   float64
#  6   jumlah_anak_remaja       3818 non-null   float64
#  7   terakhir_belanja         3818 non-null   float64
#  8   belanja_buah             3818 non-null   float64
#  9   belanja_daging           3818 non-null   float64
#  10  belanja_ikan             3818 non-null   float64
#  11  belanja_kue              3818 non-null   float64
#  12  pembelian_diskon         3818 non-null   float64
#  13  pembelian_web            3818 non-null   float64
# ...

# %% [markdown]
# # Melihat data yang relevan dengan melihat korelasi setiap feature terhadap variabel target

# %%
# Menghitung korelasi Pearson antara setiap fitur dan variabel target
train.corr()
# Out:
#                          tahun_kelahiran  pendidikan  status_pernikahan
# tahun_kelahiran                 1.000000   -0.183805          -0.094149  \
# pendidikan                     -0.183805    1.000000           0.057797
# status_pernikahan              -0.094149    0.057797           1.000000
# pendapatan                     -0.161271    0.110018           0.009450
# jumlah_anak_balita              0.240090    0.000213           0.013661
# jumlah_anak_remaja             -0.248462    0.103711           0.080041
# terakhir_belanja               -0.061932    0.017564           0.032819
# belanja_buah                   -0.075019   -0.013364           0.004348
# belanja_daging                 -0.051318    0.044399          -0.035350
# belanja_ikan                   -0.067461   -0.054618          -0.012416
# belanja_kue                    -0.012228   -0.051845          -0.005181
# pembelian_diskon               -0.081947    0.083179           0.029477
# ...

# %%
# Cek korelasi
plt.figure(figsize=(20,20))
sns.heatmap(train.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# # Data Processing

# %%
# Memilih fitur yang akan digunakan untuk prediksi
features = ['tahun_kelahiran', 'pendidikan', 'status_pernikahan', 'pendapatan',
       'jumlah_anak_balita', 'jumlah_anak_remaja', 'terakhir_belanja',
       'pembelian_diskon', 'pembelian_web', 'pembelian_toko', 'keluhan',
       'tanggal_menjadi_anggota', 'TotalAmount']
target = 'jumlah_promosi'

# %%
x = train[features]
y = train[target]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

# %%
print('X_train shape: ', x_train.shape)
print('X_test shape: ', x_test.shape)
print('y_train shape: ', y_train.shape)
print('y_test shape: ',y_test.shape)
# Out:
# X_train shape:  (3053, 13)
# X_test shape:  (764, 13)
# y_train shape:  (3053,)
# y_test shape:  (764,)

# %% [markdown]
# # Membangun Model

# %% [markdown]
# ## XGBoost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objs as go
from plotly.subplots import make_subplots
from matplotlib import colors
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, cross_val_score
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
from xgboost import XGBClassifier
from sklearn.base import clone 
# %matplotlib inline

# %%
# Initialize the XGBoost Classifier using optimal hyperparameters
xgb_opt = XGBClassifier(max_depth=9,
                        learning_rate=0.05,
                        n_estimators=330,  
                        min_child_weight=2,
                        subsample=0.9 ,
                        colsample_bytree=0.5,
                        colsample_bylevel=0.8 ,
                        reg_alpha=0.05 ,
                        reg_lambda=0.1 ,
                        max_delta_step=2 ,
                        gamma=0.1,
                        random_state=0)

# Train the XGBoost classifier
xgb_opt.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=0.8, colsample_bynode=None,
#               colsample_bytree=0.5, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.1, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None, max_delta_step=2,
#               max_depth=9, max_leaves=None, min_child_weight=2, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=330,
#               n_jobs=None, num_parallel_tree=None, objective='multi:softprob', ...)

# %%
def metrics_calculator(clf, x_test, y_test, model_name):
    '''
    This function calculates all desired performance metrics for a given model on test data.
    '''
    y_pred = clf.predict(x_test)
    result = pd.DataFrame(data=[accuracy_score(y_test, y_pred),
                                precision_score(y_test, y_pred, average='macro'),
                                recall_score(y_test, y_pred, average='macro'),
                                f1_score(y_test, y_pred, average='macro')],
                          index=['Accuracy','Macro Precision','Macro Recall','Macro F1-score'],
                          columns = [model_name])
    
    result = (result * 100).round(2).astype(str) + '%'                            
    return result

# %%
def model_evaluation(clf, x_train, x_test, y_train, y_test, model_name):
    '''
    This function provides a complete report of the model's performance including classification reports and confusion matrix
    '''
    # Set font scale
    sns.set(font_scale=1.5)
    
    # Generate classification report for training set
    y_pred_train = clf.predict(x_train)
    print("\n\t  Classification report for training set")
    print("-"*55)
    print(classification_report(y_train, y_pred_train))

    # Generate classification report for test set
    y_pred_test = clf.predict(x_test)
    print("\n\t   Classification report for test set")
    print("-"*55)
    print(classification_report(y_test, y_pred_test))
    print('\n')
    
    # Create figure and subplots 
    fig, (ax1, ax2) = plt.subplots(1, 2, dpi=90, figsize=(12, 5))
    
    # Plot confusion matrix for test set
    ConfusionMatrixDisplay.from_estimator(clf, x_test, y_test, colorbar=False, ax=ax1)
    ax1.set_title('Confusion Matrix for Test Data')                                     
    ax1.grid(False)
            
    # Report desired results as a summary in the form of a table
    result = metrics_calculator(clf, x_test, y_test, model_name)
    table = ax2.table(cellText=result.values, colLabels=result.columns, rowLabels=result.index, loc='center')
    table.scale(0.6, 3.6)
    table.set_fontsize(12)
    ax2.axis('tight')
    # Hide the axes
    ax2.axis('off')
    # set the title
    ax2.set_title('{} Performance Summary on Test Data'.format(model_name), fontsize=18)
    # Modify color 
    for key, cell in table.get_celld().items():
        if key[0] == 0:
            cell.set_color('purple')
              
    plt.tight_layout()
    plt.show()

# %%
model_evaluation(xgb_opt, x_train, x_test, y_train, y_test, 'XGBoost')
# Out:
# 	  Classification report for training set
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       786
#            1       1.00      1.00      1.00       412
#            2       1.00      1.00      1.00       311
#            3       1.00      1.00      1.00       378
#            4       1.00      1.00      1.00       412
#            5       1.00      1.00      1.00       445
#            6       1.00      1.00      1.00       309
#
#     accuracy                           1.00      3053
#    macro avg       1.00      1.00      1.00      3053
# weighted avg       1.00      1.00      1.00      3053
#
#
# 	   Classification report for test set
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.58      0.79      0.67       197
#            1       0.57      0.31      0.40       103
# ...

# %% [markdown]
# ## Random Forest

# %%
# Membuat model dengan Random Forest
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix


# Membuat objek model Random Forest
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# Melatih model menggunakan data pelatihan
rf_model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Membuat prediksi menggunakan data pengujian
y_pred_rf = rf_model.predict(x_test)

# Menghitung akurasi model
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print("Akurasi Model (Random Forest):", accuracy_rf)

# Menampilkan laporan klasifikasi
print("\nLaporan Klasifikasi (Random Forest):")
print(classification_report(y_test, y_pred_rf))

# Menampilkan matriks kebingungan (confusion matrix)
print("\nMatriks Random Forest:")
print(confusion_matrix(y_test, y_pred_rf))
# Out:
# Akurasi Model (Random Forest): 0.68717277486911
#
# Laporan Klasifikasi (Random Forest):
#               precision    recall  f1-score   support
#
#            0       0.54      0.79      0.64       197
#            1       0.59      0.21      0.31       103
#            2       0.67      0.51      0.58        78
#            3       0.81      0.82      0.81        94
#            4       0.82      0.85      0.84       103
#            5       0.80      0.87      0.83       112
#            6       0.79      0.60      0.68        77
#
#     accuracy                           0.69       764
#    macro avg       0.72      0.66      0.67       764
# weighted avg       0.70      0.69      0.67       764
#
#
# Matriks Random Forest:
# [[155   9   7   6   9   9   2]
#  [ 57  22  10   4   2   2   6]
#  [ 24   1  40   2   2   7   2]
#  [ 13   0   2  77   1   0   1]
#  [  9   1   0   3  88   1   1]
#  [  9   1   1   1   3  97   0]
#  [ 18   3   0   2   2   6  46]]

# %% [markdown]
# ## Desicion Tree

# %%
# Mengimpor model Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier

# Membuat objek model Decision Tree Classifier
dc_model = DecisionTreeClassifier(random_state=42)

# Melatih model menggunakan data pelatihan
dc_model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# Mengimpor modul evaluasi
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Membuat prediksi menggunakan data pengujian
y_pred = dc_model.predict(x_test)

# Menghitung akurasi model
accuracy = accuracy_score(y_test, y_pred)
print("Akurasi Model:", accuracy)

# Menampilkan laporan klasifikasi
print("\nLaporan Klasifikasi:")
print(classification_report(y_test, y_pred))

# Menampilkan matriks kebingungan (confusion matrix)
print("\nMatriks:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Akurasi Model: 0.5510471204188482
#
# Laporan Klasifikasi:
#               precision    recall  f1-score   support
#
#            0       0.54      0.49      0.52       197
#            1       0.26      0.24      0.25       103
#            2       0.40      0.49      0.44        78
#            3       0.72      0.71      0.72        94
#            4       0.70      0.79      0.74       103
#            5       0.69      0.68      0.68       112
#            6       0.47      0.48      0.48        77
#
#     accuracy                           0.55       764
#    macro avg       0.54      0.55      0.55       764
# weighted avg       0.55      0.55      0.55       764
#
#
# Matriks:
# [[97 36 19  8 16  9 12]
#  [33 25 14  7  6  6 12]
#  [14  7 38  3  3  8  5]
#  [ 8  9  6 67  1  3  0]
#  [ 9  4  2  2 81  3  2]
#  [ 6  6  8  2  4 76 10]
#  [11  8  7  4  5  5 37]]

# %%
# Mengimpor model SVM
from sklearn.svm import SVC

# Membuat objek model SVM
svm_model = SVC(kernel='rbf', random_state=42)

# Melatih model menggunakan data pelatihan
svm_model.fit(x_train, y_train)
# Out:
# SVC(random_state=42)

# %%
# Membuat prediksi menggunakan data pengujian
y_pred_svm = svm_model.predict(x_test)

# Menghitung akurasi model
accuracy_svm = accuracy_score(y_test, y_pred_svm)
print("Akurasi Model (SVM):", accuracy_svm)

# Menampilkan laporan klasifikasi
print("\nLaporan Klasifikasi (SVM):")
print(classification_report(y_test, y_pred_svm, zero_division=1))

# Menampilkan matriks kebingungan (confusion matrix)
print("\nMatriks:")
print(confusion_matrix(y_test, y_pred_svm))
# Out:
# Akurasi Model (SVM): 0.3102094240837696
#
# Laporan Klasifikasi (SVM):
#               precision    recall  f1-score   support
#
#            0       0.32      0.83      0.46       197
#            1       1.00      0.00      0.00       103
#            2       1.00      0.00      0.00        78
#            3       1.00      0.00      0.00        94
#            4       0.30      0.61      0.41       103
#            5       0.22      0.10      0.14       112
#            6       1.00      0.00      0.00        77
#
#     accuracy                           0.31       764
#    macro avg       0.69      0.22      0.14       764
# weighted avg       0.62      0.31      0.19       764
#
#
# Matriks:
# [[163   0   0   0  30   4   0]
#  [ 72   0   0   0  25   6   0]
#  [ 54   0   0   0  18   6   0]
#  [ 64   0   0   0  21   9   0]
#  [ 38   0   0   0  63   2   0]
#  [ 68   0   0   0  33  11   0]
#  [ 48   0   0   0  18  11   0]]

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
k_range = list(range(1,26))
scores = []
for k in k_range:
    model_knn = KNeighborsClassifier(n_neighbors=k) # konfigurasi algoritma
    model_knn.fit(x_train, y_train) # training model/classifier
    y_pred = model_knn.predict(x_test) # melakukan prediksi
    scores.append(accuracy_score(y_test, y_pred)) # evaluasi performa

# %%
plt.plot(k_range, scores)
plt.xlabel('Value of k for KNN')
plt.ylabel('Accuracy Score')
plt.title('Accuracy Scores for Values of k of k-Nearest-Neighbors')
plt.tight_layout()
plt.show()

# %%
model_knn = KNeighborsClassifier(n_neighbors=3) # konfigurasi algoritma
model_knn.fit(x_train,y_train) # training model/classifier
y_pred = model_knn.predict(x_test) # melakukan prediksi

# %%
print(accuracy_score(y_test, y_pred)) # evaluasi akurasi
# Out:
# 0.5235602094240838

# %%
print(classification_report(y_test, y_pred)) # evaluasi klasifikasi
# Out:
#               precision    recall  f1-score   support
#
#            0       0.44      0.60      0.51       197
#            1       0.38      0.29      0.33       103
#            2       0.47      0.45      0.46        78
#            3       0.54      0.53      0.53        94
#            4       0.71      0.65      0.68       103
#            5       0.67      0.60      0.63       112
#            6       0.63      0.42      0.50        77
#
#     accuracy                           0.52       764
#    macro avg       0.55      0.51      0.52       764
# weighted avg       0.53      0.52      0.52       764

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# Membuat objek model Naive Bayes
model_nb = GaussianNB()

# Melatih model menggunakan data pelatihan
model_nb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
# Melakukan prediksi pada data uji
y_pred = model_nb.predict(x_test)

# Menghitung akurasi prediksi
accuracy = accuracy_score(y_test, y_pred)
print("Akurasi Naive Bayes:", accuracy)

# Menampilkan laporan klasifikasi
print("\nLaporan Klasifikasi Naive Bayes:")
print(classification_report(y_test, y_pred_rf))

# Menampilkan matriks kebingungan (confusion matrix)
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_rf))
# Out:
# Akurasi Naive Bayes: 0.28664921465968585
#
# Laporan Klasifikasi Naive Bayes:
#               precision    recall  f1-score   support
#
#            0       0.54      0.79      0.64       197
#            1       0.59      0.21      0.31       103
#            2       0.67      0.51      0.58        78
#            3       0.81      0.82      0.81        94
#            4       0.82      0.85      0.84       103
#            5       0.80      0.87      0.83       112
#            6       0.79      0.60      0.68        77
#
#     accuracy                           0.69       764
#    macro avg       0.72      0.66      0.67       764
# weighted avg       0.70      0.69      0.67       764
#
#
# Confusion Matrix:
# [[155   9   7   6   9   9   2]
#  [ 57  22  10   4   2   2   6]
#  [ 24   1  40   2   2   7   2]
#  [ 13   0   2  77   1   0   1]
#  [  9   1   0   3  88   1   1]
#  [  9   1   1   1   3  97   0]
#  [ 18   3   0   2   2   6  46]]

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lor =  LogisticRegression(solver='liblinear',random_state=42) 
lor.fit(x_train,y_train)
# Out:
# LogisticRegression(random_state=42, solver='liblinear')

# %%
y_predLor=lor.predict(x_test)

# %%
from sklearn.ensemble import RandomForestClassifier

rndFor=RandomForestClassifier(max_depth=9, random_state=42)
rndFor.fit(x_train,y_train)
y_predRndFor=rndFor.predict(x_test)

# %%
from sklearn.metrics import f1_score
scoreLor=f1_score(y_test, y_predLor, average='macro')
scoreLor
# Out:
# 0.08785209870127404

# %%
scoreRndFor=f1_score(y_test,y_predRndFor, average='weighted')
scoreRndFor
# Out:
# 0.5574230021722169

# %% [markdown]
# ## Perbandingan Akurasi Model

# %%
models = [xgb_opt, rf_model, dc_model, svm_model, model_knn, model_nb, lor]
accuracy_scores = []
for model in models:
    y_pred = model.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    accuracy_scores.append(accuracy)
    
print(accuracy_scores)
# Out:
# [0.7146596858638743, 0.68717277486911, 0.5510471204188482, 0.3102094240837696, 0.5235602094240838, 0.28664921465968585, 0.25]

# %%
plt.bar(['XGBoost', 'RF', 'DT', 'SVM', 'KNN', 'NB', 'lor'],accuracy_scores)
plt.ylim(0.2,0.9)
plt.title('Accuracy comparision for various models', fontsize=15, color='r')
plt.xlabel('Models', fontsize=18, color='g')
plt.ylabel('Accuracy Score', fontsize=18, color='g')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Competition Submission

# %%
column_to_drop = ['ID', 'belanja_buah', 'belanja_daging', 'belanja_ikan', 'belanja_kue']

test_final = test.drop(columns=column_to_drop)
test_final
# Out:
#       tahun_kelahiran  pendidikan  status_pernikahan   pendapatan
# 0                1957           3                  6  120660151.0  \
# 1                1968           5                  3  163551821.0
# 2                1968           2                  3   29857000.0
# 3                1971           5                  3  117949098.0
# 4                1974           3                  2  164761134.0
# ...               ...         ...                ...          ...
# 3813             1984           4                  1   66320000.0
# 3814             1972           3                  3  159651946.0
# 3815             1968           4                  2   84058923.0
# 3816             1966           3                  2  106301000.0
# 3817             1973           3                  3  140353000.0
#
#       jumlah_anak_balita  jumlah_anak_remaja  terakhir_belanja
# 0                    0.0                 1.0              63.0  \
# ...

# %%
train
# Out:
#       tahun_kelahiran  pendidikan  status_pernikahan   pendapatan
# 0                1979           3                  2          0.0  \
# 1                1950           3                  2   84063000.0
# 2                1966           3                  3  127532564.0
# 3                1961           4                  2  165579620.0
# 4                1970           3                  2  117703159.0
# ...               ...         ...                ...          ...
# 3812             1955           4                  3   78199470.0
# 3813             1947           5                  2  109306000.0
# 3814             1974           4                  3  104621000.0
# 3815             1957           2                  2  110850000.0
# 3816             1961           3                  3  130512000.0
#
#       jumlah_anak_balita  jumlah_anak_remaja  terakhir_belanja  belanja_buah
# 0                    0.0                 1.0               0.0       50575.0  \
# ...

# %%
test_final
# Out:
#       tahun_kelahiran  pendidikan  status_pernikahan   pendapatan
# 0                1957           3                  6  120660151.0  \
# 1                1968           5                  3  163551821.0
# 2                1968           2                  3   29857000.0
# 3                1971           5                  3  117949098.0
# 4                1974           3                  2  164761134.0
# ...               ...         ...                ...          ...
# 3813             1984           4                  1   66320000.0
# 3814             1972           3                  3  159651946.0
# 3815             1968           4                  2   84058923.0
# 3816             1966           3                  2  106301000.0
# 3817             1973           3                  3  140353000.0
#
#       jumlah_anak_balita  jumlah_anak_remaja  terakhir_belanja
# 0                    0.0                 1.0              63.0  \
# ...

# %%
# Define features(X) and output labels(y)
x = train[features]
y = train[target]

# %%
# Target prediction for test.csv samples using relavant features
y_pred = rf_model.predict(test_final)

# %%
submission = pd.DataFrame({'ID': test['ID'], 'jumlah_promosi': y_pred})
submission
# Out:
#         ID  jumlah_promosi
# 0     2241               0
# 1     2274               0
# 2     1107               0
# 3     4478               0
# 4     5080               0
# ...    ...             ...
# 3813   271               0
# 3814  3334               0
# 3815  3478               1
# 3816    89               0
# 3817  2151               0
#
# [3818 rows x 2 columns]

# %%
submission.to_csv('Submission_baru.csv', index=False)

# %%
final = pd.read_csv('Submission_baru.csv')
final.head(50)
# Out:
#       ID  jumlah_promosi
# 0   2241               0
# 1   2274               0
# 2   1107               0
# 3   4478               0
# 4   5080               0
# 5   5725               4
# 6    456               1
# 7   1711               1
# 8   2940               0
# 9   3031               0
# 10  3551               0
# 11  5987               0
# 12  6925               0
# 13  5735               0
# 14   298               0
# 15  4020               0
# 16  3127               0
# 17  7432               0
# 18  7375               0
# 19  1996               1
# 20  5966               0
# 21  6697               0
# 22  3544               0
# 23  7122               0
# 24  1379               0
# 25   505               0
# 26   224               0
# 27  3024               0
# 28  2946               0
# 29   153               0
# 30   229               0
# 31  7411               0
# 32  2655               0
# 33  6972               0
# 34   320               0
# 35  5205               0
# ...
